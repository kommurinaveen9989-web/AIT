# %% [markdown]
# <a href="https://colab.research.google.com/github/kommurinaveen9989-web/AIT/blob/main/AIT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Naveen")
# Out:
# Naveen

# %%
for i in range(1,11):
  i="Naveen"
  print(i)
# Out:
# Naveen
# Naveen
# Naveen
# Naveen
# Naveen
# Naveen
# Naveen
# Naveen
# Naveen
# Naveen

# %%
matrix=[1,2,
        3,4]
print(matrix)
# Out:
# [1, 2, 3, 4]

# %%
matrix1=[1,2,3,4]
matrix2=[3,4,5,6]
result=[a+b for a,b in zip(matrix1,matrix2)]
print(result)
# Out:
# [4, 6, 8, 10]

# %%
matrix=[
    [10,20,30]
]
data={
    "a":matrix[0][0],
    "b":matrix[0][1],
    "c":matrix[0][2]
}
print(data["a"])
print(data["b"])
print(data["c"])
# Out:
# 10
# 20
# 30
