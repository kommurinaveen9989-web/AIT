# %% [markdown]
# <a href="https://colab.research.google.com/github/kommurinaveen9989-web/AIT/blob/main/BFS_%26_DFS-1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# BFS
# > Add blockquote

# %%
from collections import deque

def bfs(graph, start):
    visited = set()
    queue = deque([start])
    visited.add(start)
    traversal_order = []

    while queue:
        node = queue.popleft()
        traversal_order.append(node)

        for neighbor in graph[node]:
            if neighbor not in visited:
                visited.add(neighbor)
                queue.append(neighbor)

    return traversal_order
graph = {
    'A': ['B', 'C'],
    'B': [],
    'C': [],

}
print("BFS Traversal Order:", bfs(graph, 'A'))
# Out:
# BFS Traversal Order: ['A', 'B', 'C']

# %% [markdown]
# DFS

# %%
def dfs(graph, start, visited=None):
    if visited is None:
        visited = set()
    visited.add(start)
    traversal_order = [start]

    for neighbor in graph[start]:
        if neighbor not in visited:
            traversal_order.extend(dfs(graph, neighbor, visited))

    return traversal_order
graph = {
    'A': ['B', 'C'],
    'B': [],
    'C': [],

}
print("DFS Traversal Order:", dfs(graph, 'A'))
# Out:
# DFS Traversal Order: ['A', 'B', 'C']
